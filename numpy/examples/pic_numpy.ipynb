# %% [markdown]
# # Операции над картинками

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://dfedorov.spb.ru/python3/book_urite.jpg
# Out:
# --2021-12-05 18:44:07--  https://dfedorov.spb.ru/python3/book_urite.jpg
# Resolving dfedorov.spb.ru (dfedorov.spb.ru)... 92.53.96.207, 2a03:6f00:1::5c35:60cf
# Connecting to dfedorov.spb.ru (dfedorov.spb.ru)|92.53.96.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63200 (62K) [image/jpeg]
# Saving to: ‘book_urite.jpg’
#
# book_urite.jpg      100%[===================>]  61.72K  --.-KB/s    in 0.1s
#
# 2021-12-05 18:44:09 (479 KB/s) - ‘book_urite.jpg’ saved [63200/63200]

# %%
image = plt.imread("book_urite.jpg")
plt.imshow(image)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image + 50)

# %%
plt.imshow(image // 2)

# %%
plt.imshow(np.cos(np.pi / 2 * image / 255))

# %%
image.shape
# Out:
# (448, 320, 3)

# %%
image_trans = np.transpose(image, (1, 0, 2))
print(image_trans.shape)
plt.imshow(image_trans)
# Out:
# (320, 448, 3)

# %%
plt.imshow(image[100:, :200])
